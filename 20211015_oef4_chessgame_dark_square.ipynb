# %% [markdown]
# <a href="https://colab.research.google.com/github/katrienvanmeulder/STEM5-21-22/blob/main/20211015_oef4_chessgame_dark_square.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Achtergrondinformatie
#
# Bekijk even het schaakbord in onderstaande figuur.
#
# ![schaakbord.png](data:image/png;base64,...)
#
# Het bord bestaat uit zwarte (donkere) en witte (lichte) velden.
#
# Elk veld wordt aangeduid door een combinatie van kolomnummer (k) en rijnummer (r). Bij het verwijzen naar een veld geven we steeds eerst het kolomnummer door en dan pas het rijnummer.
#
# Opgelet!
#
# - De kolom helemaal links heeft kolomnummer 1, de kolom helemaal rechts heeft kolomnummer 8.
#
# - De rij helemaal onderaan heeft rijnummer 1, de rij helemaal bovenaan heeft rijnummer 8. <– !!!!
#
# - Het veld (1,1), het veld links, onderaan is een ‘donker’ veld.
#
# - Het veld (6,3), het veld in de 6de kolom, en 3de rij is een ‘licht’ veld.

# %% [markdown]
# # Opgave
#
# - Gegeven een veld op het schaakbord.
#
# - Schrijf een programma dat antwoord geeft op de vraag “Is het een ‘donker’ of ‘licht’ veld?”.

# %% [markdown]
# # Een mogelijke aanpak
# Het programma …
#
# - vraagt de gebruiker naar het kolomnummer van het veld (bv. kolom, k, …).
# - vraagt de gebruiker naar het rijnummer van het veld (bv. rij, r, …).
# - evalueert of het veld een “donker” of “licht” veld is.
# - drukt het gevonden resultaat af onder de vorm “**DONKER VELD**” of
# “**LICHT VELD**”.
